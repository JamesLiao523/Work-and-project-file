# %%
import ffn
import matplotlib.pyplot as plt
import pandas as pd
import time
from ffn.utils import clean_ticker
# %matplotlib inline  


portfolio= ffn.get("2454.tw,4966.two", start = "2014-01-01")

portfolio.plot(grid = True)
portfolio.plot.hist()
portfolio.corr()
# Out:
#            2454tw   4966two
# 2454tw   1.000000  0.751897
# 4966two  0.751897  1.000000

# %%
symbol = portfolio["2454tw"]
portfolio.sort_values(by='Date', ascending=False, na_position='first')
portfolio["index"] = range(len(portfolio))
portfolio.head(5)
# Out:
#                 2454tw     4966two  index
# Date
# 2014-01-02  345.060822  213.834610      0
# 2014-01-03  340.757324  207.725052      1
# 2014-01-06  337.627533  199.869904      2
# 2014-01-07  327.455627  213.834610      3
# 2014-01-08  318.457489  207.288651      4

# %%
cols = portfolio.columns.tolist()
Temp = cols[2]
cols[2]=cols[1]
cols[1]=cols[0]
cols[0]=Temp
portfolio = portfolio[cols]
portfolio.head()
# Out:
#             index      2454tw     4966two
# Date
# 2014-01-02      0  345.060822  213.834610
# 2014-01-03      1  340.757324  207.725052
# 2014-01-06      2  337.627533  199.869904
# 2014-01-07      3  327.455627  213.834610
# 2014-01-08      4  318.457489  207.288651

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

tsla = portfolio["tsla"]
portfolio["z_score"] = ((tsla - np.mean(tsla))/np.std(tsla))
zscore = portfolio["z_score"] 
portfolio.head()
# Out:
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             index       tsla   z_score
# Date
# 2013-12-31      0  30.086000 -1.953162
# 2014-01-02      1  30.020000 -1.959110
# 2014-01-03      2  29.912001 -1.968845
# 2014-01-06      3  29.400000 -2.014994
# 2014-01-07      4  29.872000 -1.972451

# %%
plt.plot(portfolio["index"], zscore, color='b')

# %%
zscore.plot.hist()

# %%
zscore_high = 2.0
zscore_low = 0.5

buy_signal = (zscore >= -(zscore_high))
sell_signal = (zscore <= -(zscore_low))
short_signal = (zscore >= zscore_high)
cover_signal = (zscore <= zscore_low)

# %%
long_position = False
portfolio["PV"] = 0.0
turnovers = 0


for i, t in enumerate(portfolio.index):
    
    if not long_position:   #無持倉狀態為true時
        
        payoff = 0
        portfolio["PV"].iloc[i] = portfolio["PV"].iloc[i - 1] + payoff
        
        if buy_signal[t]:    #如果有買進訊號
            long_position = True
            turnovers = turnovers + 1
            print(">" * 5, "Create a long position.")
    else:
        
        payoff = portfolio[name].iloc[i] - portfolio[name].iloc[i - 1]     #累積損益
        portfolio["PV"].iloc[i] = portfolio["PV"].iloc[i - 1] + payoff
        

print("Number of turnovers:", turnovers)
# Out:
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\j4a3m\anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# >>>>> Create a long position.
# Number of turnovers: 1

# %%
short_position = False
portfolio["PV2"] = 0.0
turnovers = 0     

for i, t in enumerate(portfolio.index):
                       
    if not short_position:   #無持倉狀態為true時
        payoff = 0       
        portfolio["PV2"].iloc[i] = portfolio["PV2"].iloc[i - 1] + payoff
        
        if short_signal[t]:    
            short_position = True
            turnovers = turnovers + 1
            print(">" * 5, "Create a short position.")
    else:
        
        payoff = portfolio[name].iloc[i] - portfolio[name].iloc[i - 1]     #累積損益
        portfolio["PV"].iloc[i] = portfolio["PV"].iloc[i - 1] + payoff
        
        if cover_signal[t]:                                   #平倉訊號
            position = False
            print("<" * 5, "Close a short position.")
            print("{} -> {:.2f} -> {:.2f}".format(t, portfolio[name][t], portfolio["PV2"][t]))

print("Number of turnovers:", turnovers)
# Out:
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d152b00c7757> in <module>
#       7     if not short_position:   #無持倉狀態為true時
#       8         payoff = 0
# ----> 9         portfolio["PV2"].iloc[i] = portfolio["PV2"].iloc[i - 1] + payoff
#      10
#      11         if short_signal[t]:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     655             self.obj._data = self.obj._data.setitem(indexer=indexer,
#     656                                                     value=value)
# --> 657             self.obj._maybe_update_cacher(clear=True)
#     658
#     659     def _align_series(self, indexer, ser, multiindex_indexer=False):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3142
#    3143         if verify_is_copy:
# -> 3144             self._check_setitem_copy(stacklevel=5, t='referant')
#    3145
#    3146         if clear:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3244             try:
#    3245                 gc.collect(2)
# -> 3246                 if not gc.get_referents(self._is_copy()):
#    3247                     self._is_copy = None
#    3248                     return
#
# KeyboardInterrupt:

# %%
portfolio.head()
# Out:
#             index       tsla   z_score        PV  PV2
# Date
# 2013-12-31      0  30.086000 -1.953162  0.000000  0.0
# 2014-01-02      1  30.020000 -1.959110 -0.066000  0.0
# 2014-01-03      2  29.912001 -1.968845 -0.174000  0.0
# 2014-01-06      3  29.400000 -2.014994 -0.686001  0.0
# 2014-01-07      4  29.872000 -1.972451 -0.214001  0.0

# %%
portfolio["PV"]=portfolio["PV"]+portfolio["PV2"]
portfolio["DD of our strategy"] = (portfolio["PV"] - portfolio["PV"].cummax()).cummin()  #cummax=(部位最小值-部位最大值)圖形的最低點(cummin)
dd_idx = portfolio["DD of our strategy"].idxmin()
# Out:
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
portfolio["buy&hold"] = portfolio[name].diff().cumsum()
portfolio["DD of buy&hold"] = (portfolio["buy&hold"] - portfolio["buy&hold"].cummax()).cummin()
dd_idx2 = portfolio["DD of buy&hold"].idxmin()
# Out:
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\j4a3m\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
portfolio[["PV", "buy&hold"]].plot(style = ".-", grid = True, figsize = (12, 6))
ax = portfolio["DD of our strategy"].plot(style = "--", grid = True)
ax = portfolio["DD of buy&hold"].plot(style = "--", grid = True)
ax.legend(["Our strategy", "Benchmark: buy&hold", "DD of our strategy", "DD of buy&hold"])
